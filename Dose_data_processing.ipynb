# %%
import os
import shutil
import cv2
import numpy as np

# %%
def mkdir(path):
    folder = os.path.exists(path)
    if not folder:
        os.makedirs(path)

# %%
mkdir('./iso_drug_image/whole_images')
for ch in range(1, 5): 
    mkdir(f'./iso_drug_image/whole_images/ch{ch}')

# %%
mkdir('./angii_drug_image/whole_images')
for ch in range(1, 5): 
    mkdir(f'./angii_drug_image/whole_images/ch{ch}')

# %%
missing_images = []

# %% [markdown]
# ## angii给药数据处理

# %% [markdown]
# ### angii给药图像数据硬盘拷贝

# %%
# 6.19-1
prefix = "061901_"
src = 'E:/AXC-2022-6.19-1__2022-06-19T17_34_31-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：4-11列
for r in range(2, 8):
    for c in range(4, 12):
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 6.24-1
prefix = "062401_"
src = 'E:/AXC-2022-6.24-1__2022-06-24T13_49_21-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：4-11列
for r in range(2, 8):
    for c in range(4, 12):
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 6.26-1
prefix = "062601_"
src = 'E:/AXC-2022-6.26-1__2022-06-26T14_44_42-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 6.27-1
prefix = "062701_"
src = 'E:/AXC-2022-6.27-1__2022-06-27T13_23_58-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 6.29-1
prefix = "062901_"
src = 'E:/AXC-2022-6.29-1__2022-06-29T14_09_09-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 6.30-1
prefix = "063001_"
src = 'E:/axc-2022-6.30-1__2022-06-30T14_28_59-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.2-1
prefix = "070201_"
src = 'E:/AXC-2022-7.2-1__2022-07-02T14_31_38-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.3-1
prefix = "070301_"
src = 'E:/AXC-2022-7.3-1__2022-07-03T15_12_44-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.5-1
prefix = "070501_"
src = 'F:/AXC-2022-7.5-1__2022-07-05T14_44_27-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.6-1
prefix = "070601_"
src = 'F:/AXC-2022-7.6-1__2022-07-06T14_10_49-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.8-1
prefix = "070801_"
src = 'F:/AXC-2022-7-8-1__2022-07-08T14_52_44-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.9-1
prefix = "070901_"
src = 'F:/AXC-2022-7.9-1__2022-07-09T14_06_53-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.11-1
prefix = "071101_"
src = 'F:/AXC-2022-7.11-1__2022-07-11T13_48_09-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.12-1
prefix = "071201_"
src = 'F:/AXC-2022-7.12-1__2022-07-12T13_37_41-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.14-1
prefix = "071401_"
src = 'F:/AXC-2022-7.13-1__2022-07-14T14_07_44-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.15-1
prefix = "071501_"
src = 'F:/AXC-2022-7.15-1__2022-07-15T14_11_21-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.17-1
prefix = "071701_"
src = 'F:/AXC-2022-7.17-1__2022-07-17T14_07_54-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 8.1-1
prefix = "080101_"
src = 'F:/AXC-2022-8.1-1-1__2022-08-01T18_11_40-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 9.1-1 9.1-1只有9个视野
prefix = "090101_"
src = 'E:/AXC-2022-9.1-1__2022-09-01T14_13_51-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2-9列 11列
columns = [i for i in range(2, 12)]
columns.remove(10)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    # print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 9.3-1 
prefix = "090301_"
src = 'E:/AXC-2022-9.3-1__2022-09-03T13_20_56-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    # print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 9.4-1 
prefix = "090401_"
src = 'E:/AXC-2022.9.4-1__2022-09-04T13_04_57-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    # print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 10.2-1 
prefix = "100201_"
src = 'E:/AXC-2022-1002-1__2022-10-02T15_53_01-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    # print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 10.15-1 
prefix = "101501_"
src = 'E:/AXC-2022-1015-1__2022-10-15T13_05_07-Measurement 1/Images/'
dsc = './angii_drug_image/whole_images/'

# 给药图像：2列 5-11列
columns = [i for i in range(2, 12)]
columns.remove(3)
columns.remove(4)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    # print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %% [markdown]
# ### angii给药图像裁剪

# %%
mkdir('./angii_drug_image/crop_images')
for ch in range(1, 5):
    mkdir(f'./angii_drug_image/crop_images/ch{ch}_crop')

# %%
# 定义寻找细胞核中心坐标的函数，返回一个包含各中心坐标（元组）的列表
def find_centers(img):
    gradX = cv2.Sobel(img, ddepth=cv2.CV_32F, dx=1, dy=0, ksize=-1)
    gradY = cv2.Sobel(img, ddepth=cv2.CV_32F, dx=0, dy=1, ksize=-1)

    gradient = cv2.subtract(gradX, gradY)
    gradient = cv2.convertScaleAbs(gradient)

    blurred = cv2.blur(gradient,(9, 9))
    (_, thresh) = cv2.threshold(blurred, 247, 255, cv2.THRESH_BINARY)

    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (11, 11))
    closed = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

    closed = cv2.erode(closed, None, iterations=4)
    closed = cv2.dilate(closed, None, iterations=4)

    (cnts, _) = cv2.findContours(closed.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cs = sorted(cnts, key=cv2.contourArea, reverse=True)[:int(len(cnts)*0.66)]

    # 图像中各细胞核的中心
    centers = []
    for c in cs:
        rect = cv2.minAreaRect(c)
        center = rect[0]
        centers.append(center)

    return centers

# %%
filenames_ch1 = os.listdir('./angii_drug_image/whole_images/ch1/')
for fn_ch1 in filenames_ch1:
    img_nuclei = cv2.imread(f'./angii_drug_image/whole_images/ch1/{fn_ch1}', cv2.IMREAD_UNCHANGED)
    centers = find_centers(img=img_nuclei)

    fn_ch2 = f"{fn_ch1[:22]}"+"2"+f"{fn_ch1[23:]}"
    fn_ch3 = f"{fn_ch1[:22]}"+"3"+f"{fn_ch1[23:]}"
    fn_ch4 = f"{fn_ch1[:22]}"+"4"+f"{fn_ch1[23:]}"

    img2 = cv2.imread(os.path.join('./angii_drug_image/whole_images/ch2/',fn_ch2), cv2.IMREAD_UNCHANGED)
    img3 = cv2.imread(os.path.join('./angii_drug_image/whole_images/ch3/',fn_ch3), cv2.IMREAD_UNCHANGED)
    img4 = cv2.imread(os.path.join('./angii_drug_image/whole_images/ch4/',fn_ch4), cv2.IMREAD_UNCHANGED)

    idx = 0
    for center in centers:
        x = int(center[0])
        y = int(center[1])
        if y-150 >= 0 and x-150 >= 0 and y+150 <= 1080 and x+150 <= 1080:
            img1_crop = img_nuclei[(y-150):(y+150), (x-150):(x+150)]
            img2_crop = img2[(y-150):(y+150), (x-150):(x+150)]
            img3_crop = img3[(y-150):(y+150), (x-150):(x+150)]
            img4_crop = img4[(y-150):(y+150), (x-150):(x+150)]

            idx +=1

            cv2.imwrite(f"./angii_drug_image/crop_images/ch1_crop/{fn_ch1[:-14]}"+f"crop{'%02d'%idx}"+".tiff", img1_crop)
            cv2.imwrite(f"./angii_drug_image/crop_images/ch2_crop/{fn_ch2[:-14]}"+f"crop{'%02d'%idx}"+".tiff", img2_crop)
            cv2.imwrite(f"./angii_drug_image/crop_images/ch3_crop/{fn_ch3[:-14]}"+f"crop{'%02d'%idx}"+".tiff", img3_crop)
            cv2.imwrite(f"./angii_drug_image/crop_images/ch4_crop/{fn_ch4[:-14]}"+f"crop{'%02d'%idx}"+".tiff", img4_crop)

# %% [markdown]
# ### angii给药图像通道合并

# %%
mkdir('./angii_drug_image/crop_images/crop_merge_ch1ch2ch3ch4')

fns1 = os.listdir("./angii_drug_image/crop_images/ch1_crop/")
fns2 = os.listdir("./angii_drug_image/crop_images/ch2_crop/")
fns3 = os.listdir("./angii_drug_image/crop_images/ch3_crop/")
fns4 = os.listdir("./angii_drug_image/crop_images/ch4_crop/")

fns1.sort()
fns2.sort()
fns3.sort()
fns4.sort()

for i in range(len(fns1)):
    ch1 = cv2.imread(f'./angii_drug_image/crop_images/ch1_crop/{fns1[i]}', cv2.IMREAD_UNCHANGED)
    ch2 = cv2.imread(f'./angii_drug_image/crop_images/ch2_crop/{fns2[i]}', cv2.IMREAD_UNCHANGED)
    ch3 = cv2.imread(f'./angii_drug_image/crop_images/ch3_crop/{fns3[i]}', cv2.IMREAD_UNCHANGED)
    ch4 = cv2.imread(f'./angii_drug_image/crop_images/ch4_crop/{fns4[i]}', cv2.IMREAD_UNCHANGED)

    ch_merge = cv2.merge([ch1, ch2, ch3, ch4])
    cv2.imwrite(f'./angii_drug_image/crop_images/crop_merge_ch1ch2ch3ch4/{fns1[i][:20]}{fns1[i][-11:]}', ch_merge)

# %%
mkdir('./angii_drug_image/crop_images/crop_merge_ch1ch3ch4')

fns1 = os.listdir("./angii_drug_image/crop_images/ch1_crop/")
# fns2 = os.listdir("./angii_drug_image/crop_images/ch2_crop/")
fns3 = os.listdir("./angii_drug_image/crop_images/ch3_crop/")
fns4 = os.listdir("./angii_drug_image/crop_images/ch4_crop/")

fns1.sort()
# fns2.sort()
fns3.sort()
fns4.sort()

for i in range(len(fns1)):
    ch1 = cv2.imread(f'./angii_drug_image/crop_images/ch1_crop/{fns1[i]}', cv2.IMREAD_UNCHANGED)
    # ch2 = cv2.imread(f'./angii_drug_image/crop_images/ch2_crop/{fns2[i]}', cv2.IMREAD_UNCHANGED)
    ch3 = cv2.imread(f'./angii_drug_image/crop_images/ch3_crop/{fns3[i]}', cv2.IMREAD_UNCHANGED)
    ch4 = cv2.imread(f'./angii_drug_image/crop_images/ch4_crop/{fns4[i]}', cv2.IMREAD_UNCHANGED)

    ch_merge = cv2.merge([ch1, ch3, ch4])
    cv2.imwrite(f'./angii_drug_image/crop_images/crop_merge_ch1ch3ch4/{fns1[i][:20]}{fns1[i][-11:]}', ch_merge)

# %%
mkdir('./angii_drug_image/crop_images/crop_merge_ch2ch3ch4')

# fns1 = os.listdir("./angii_drug_image/crop_images/ch1_crop/")
fns2 = os.listdir("./angii_drug_image/crop_images/ch2_crop/")
fns3 = os.listdir("./angii_drug_image/crop_images/ch3_crop/")
fns4 = os.listdir("./angii_drug_image/crop_images/ch4_crop/")

# fns1.sort()
fns2.sort()
fns3.sort()
fns4.sort()

for i in range(len(fns2)):
    # ch1 = cv2.imread(f'./angii_drug_image/crop_images/ch1_crop/{fns1[i]}', cv2.IMREAD_UNCHANGED)
    ch2 = cv2.imread(f'./angii_drug_image/crop_images/ch2_crop/{fns2[i]}', cv2.IMREAD_UNCHANGED)
    ch3 = cv2.imread(f'./angii_drug_image/crop_images/ch3_crop/{fns3[i]}', cv2.IMREAD_UNCHANGED)
    ch4 = cv2.imread(f'./angii_drug_image/crop_images/ch4_crop/{fns4[i]}', cv2.IMREAD_UNCHANGED)

    ch_merge = cv2.merge([ch2, ch3, ch4])
    cv2.imwrite(f'./angii_drug_image/crop_images/crop_merge_ch2ch3ch4/{fns2[i][:20]}{fns2[i][-11:]}', ch_merge)

# %% [markdown]
# ## iso给药图像数据处理

# %% [markdown]
# ### iso给药图像数据硬盘拷贝

# %%
# 6.19-2
prefix = "061902_"
src = 'E:/AXC-2022-6.19-2__2022-06-19T13_42_58-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：4-11列
for r in range(2, 8):
    for c in range(4, 12):
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 6.24-2
prefix = "062402_"
src = 'E:/AXC-2022-6.24-2__2022-06-24T17_25_42-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：4-11列
for r in range(2, 8):
    for c in range(4, 12):
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 6.26-2
prefix = "062602_"
src = 'E:/AXC-2022-6.26-2__2022-06-26T18_43_51-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 6.27-2
prefix = "062702_"
src = 'E:/AXC-2022-6.27-2__2022-06-27T17_23_48-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 6.29-2
prefix = "062902_"
src = 'E:/AXC-2022-6.29-2__2022-06-29T18_03_41-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 6.30-2
prefix = "063002_"
src = 'E:/axc-2022-6.30-2__2022-06-30T18_48_31-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.2-2
prefix = "070202_"
src = 'E:/AXC-2022-7.2-2__2022-07-02T18_43_33-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.3-2
prefix = "070302_"
src = 'E:/AXC-2022-7.3-2__2022-07-03T18_19_01-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.5-2
prefix = "070502_"
src = 'F:/AXC-2022-7.5-2__2022-07-05T18_09_05-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.6-2
prefix = "070602_"
src = 'F:/AXC-2022-7.6-2__2022-07-06T18_58_40-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.8-2
prefix = "070802_"
src = 'F:/AXC-2022-7-8-2__2022-07-08T18_39_00-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.9-2
prefix = "070902_"
src = 'F:/AXC-2022-7.9-2__2022-07-09T17_15_48-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.11-2
prefix = "071102_"
src = 'F:/AXC-2022-7.11-2__2022-07-11T17_05_50-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.12-2
prefix = "071202_"
src = 'F:/AXC-2022-7.12-2__2022-07-12T18_07_53-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.14-2
prefix = "071402_"
src = 'F:/AXC-2022-7.14-2__2022-07-14T18_03_22-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.15-2
prefix = "071502_"
src = 'F:/AXC-2022-7.15--2__2022-07-15T18_06_38-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 7.17-2
prefix = "071702_"
src = 'F:/AXC-2022-7.17-2__2022-07-17T17_40_06-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 8.1-2
prefix = "080102_"
src = 'E:/AXC-2022-8.1-2-2__2022-08-01T15_00_58-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 9.1-2 
prefix = "090102_"
src = 'E:/AXC-2022-9.1-2__2022-09-01T16_50_36-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    # print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 9.3-2 
prefix = "090302_"
src = 'E:/AXC-2022-9.3-2__2022-09-03T16_33_23-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    # print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 9.4-2 
prefix = "090402_"
src = 'E:/AXC-2022.9.4-2__2022-09-04T16_25_24-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    # print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 10.2-2 
prefix = "100202_"
src = 'E:/AXC-20221002-2__2022-10-02T19_23_57-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 4-11列
columns = [i for i in range(2, 12)]
columns.remove(3)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    # print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %%
# 10.15-2 
prefix = "101502_"
src = 'E:/AXC-2022-1015-2__2022-10-15T16_33_49-Measurement 1/Images/'
dsc = './iso_drug_image/whole_images/'

# 给药图像：2列 5-11列
columns = [i for i in range(2, 12)]
columns.remove(3)
columns.remove(4)

for r in range(2, 8):
    for c in columns:
        for f in range(1, 12):
            for ch in range(1, 5):
                filename = f"r{'%02d'%r}c{'%02d'%c}f{'%02d'%f}p17-ch{ch}sk1fk1fl1.tiff"
                filename2 = prefix + filename
                if os.path.exists(os.path.join(src, filename)):
                    shutil.copyfile(os.path.join(src, filename), os.path.join(dsc, f"ch{ch}", filename2))
                else:
                    # print(f"{filename2} doesn't exist")
                    missing_images.append(filename2)

# %% [markdown]
# ### iso给药图像裁剪

# %%
mkdir('./iso_drug_image/crop_images')
for ch in range(1, 5):
    mkdir(f'./iso_drug_image/crop_images/ch{ch}_crop')

# %%
# 定义寻找细胞核中心坐标的函数，返回一个包含各中心坐标（元组）的列表
def find_centers(img):
    gradX = cv2.Sobel(img, ddepth=cv2.CV_32F, dx=1, dy=0, ksize=-1)
    gradY = cv2.Sobel(img, ddepth=cv2.CV_32F, dx=0, dy=1, ksize=-1)

    gradient = cv2.subtract(gradX, gradY)
    gradient = cv2.convertScaleAbs(gradient)

    blurred = cv2.blur(gradient,(9, 9))
    (_, thresh) = cv2.threshold(blurred, 247, 255, cv2.THRESH_BINARY)

    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (11, 11))
    closed = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

    closed = cv2.erode(closed, None, iterations=4)
    closed = cv2.dilate(closed, None, iterations=4)

    (cnts, _) = cv2.findContours(closed.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cs = sorted(cnts, key=cv2.contourArea, reverse=True)
    # cs = sorted(cnts, key=cv2.contourArea, reverse=True)[:int(len(cnts)*0.66)]

    # 图像中各细胞核的中心
    centers = []
    for c in cs:
        rect = cv2.minAreaRect(c)
        center = rect[0]
        centers.append(center)

    return centers

# %%
filenames_ch1 = os.listdir('./iso_drug_image/whole_images/ch1/')
for fn_ch1 in filenames_ch1:
    img_nuclei = cv2.imread(f'./iso_drug_image/whole_images/ch1/{fn_ch1}', cv2.IMREAD_UNCHANGED)
    centers = find_centers(img=img_nuclei)

    fn_ch2 = f"{fn_ch1[:22]}"+"2"+f"{fn_ch1[23:]}"
    fn_ch3 = f"{fn_ch1[:22]}"+"3"+f"{fn_ch1[23:]}"
    fn_ch4 = f"{fn_ch1[:22]}"+"4"+f"{fn_ch1[23:]}"

    img2 = cv2.imread(os.path.join('./iso_drug_image/whole_images/ch2/',fn_ch2), cv2.IMREAD_UNCHANGED)
    img3 = cv2.imread(os.path.join('./iso_drug_image/whole_images/ch3/',fn_ch3), cv2.IMREAD_UNCHANGED)
    img4 = cv2.imread(os.path.join('./iso_drug_image/whole_images/ch4/',fn_ch4), cv2.IMREAD_UNCHANGED)

    idx = 0
    for center in centers:
        x = int(center[0])
        y = int(center[1])
        if y-150 >= 0 and x-150 >= 0 and y+150 <= 1080 and x+150 <= 1080:
            img1_crop = img_nuclei[(y-150):(y+150), (x-150):(x+150)]
            img2_crop = img2[(y-150):(y+150), (x-150):(x+150)]
            img3_crop = img3[(y-150):(y+150), (x-150):(x+150)]
            img4_crop = img4[(y-150):(y+150), (x-150):(x+150)]

            idx +=1

            cv2.imwrite(f"./iso_drug_image/crop_images/ch1_crop/{fn_ch1[:-14]}"+f"crop{'%02d'%idx}"+".tiff", img1_crop)
            cv2.imwrite(f"./iso_drug_image/crop_images/ch2_crop/{fn_ch2[:-14]}"+f"crop{'%02d'%idx}"+".tiff", img2_crop)
            cv2.imwrite(f"./iso_drug_image/crop_images/ch3_crop/{fn_ch3[:-14]}"+f"crop{'%02d'%idx}"+".tiff", img3_crop)
            cv2.imwrite(f"./iso_drug_image/crop_images/ch4_crop/{fn_ch4[:-14]}"+f"crop{'%02d'%idx}"+".tiff", img4_crop)

# %%
filenames_ch1 = os.listdir('./iso_drug_image/whole_images/ch1/')
parthenolide_loc = [f"070302_r{'%02d'%r}c10" for r in range(5, 8)]
parthenolide_fn = [i for i in filenames_ch1 if i[:13] in parthenolide_loc]

for fn_ch1 in parthenolide_fn:
    img_nuclei = cv2.imread(f'./iso_drug_image/whole_images/ch1/{fn_ch1}', cv2.IMREAD_UNCHANGED)
    centers = find_centers(img=img_nuclei)

    fn_ch2 = f"{fn_ch1[:22]}"+"2"+f"{fn_ch1[23:]}"
    fn_ch3 = f"{fn_ch1[:22]}"+"3"+f"{fn_ch1[23:]}"
    fn_ch4 = f"{fn_ch1[:22]}"+"4"+f"{fn_ch1[23:]}"

    img2 = cv2.imread(os.path.join('./iso_drug_image/whole_images/ch2/',fn_ch2), cv2.IMREAD_UNCHANGED)
    img3 = cv2.imread(os.path.join('./iso_drug_image/whole_images/ch3/',fn_ch3), cv2.IMREAD_UNCHANGED)
    img4 = cv2.imread(os.path.join('./iso_drug_image/whole_images/ch4/',fn_ch4), cv2.IMREAD_UNCHANGED)

    idx = 0
    for center in centers:
        x = int(center[0])
        y = int(center[1])
        if y-150 >= 0 and x-150 >= 0 and y+150 <= 1080 and x+150 <= 1080:
            img1_crop = img_nuclei[(y-150):(y+150), (x-150):(x+150)]
            img2_crop = img2[(y-150):(y+150), (x-150):(x+150)]
            img3_crop = img3[(y-150):(y+150), (x-150):(x+150)]
            img4_crop = img4[(y-150):(y+150), (x-150):(x+150)]

            idx +=1

            cv2.imwrite(f"./iso_drug_image/crop_images/parthenolide/ch1_crop/{fn_ch1[:-14]}"+f"crop{'%02d'%idx}"+".tiff", img1_crop)
            cv2.imwrite(f"./iso_drug_image/crop_images/parthenolide/ch2_crop/{fn_ch2[:-14]}"+f"crop{'%02d'%idx}"+".tiff", img2_crop)
            cv2.imwrite(f"./iso_drug_image/crop_images/parthenolide/ch3_crop/{fn_ch3[:-14]}"+f"crop{'%02d'%idx}"+".tiff", img3_crop)
            cv2.imwrite(f"./iso_drug_image/crop_images/parthenolide/ch4_crop/{fn_ch4[:-14]}"+f"crop{'%02d'%idx}"+".tiff", img4_crop)

# %%
img_nuclei = cv2.imread(f'./iso_drug_image/whole_images/ch1/{parthenolide_fn[0]}', cv2.IMREAD_UNCHANGED)
centers = find_centers(img=img_nuclei)

# %% [markdown]
# ### iso给药图像通道合并

# %%
mkdir('./iso_drug_image/crop_images/crop_merge_ch1ch3ch4')

fns1 = os.listdir("./iso_drug_image/crop_images/ch1_crop/")
# fns2 = os.listdir("./angii_drug_image/crop_images/ch2_crop/")
fns3 = os.listdir("./iso_drug_image/crop_images/ch3_crop/")
fns4 = os.listdir("./iso_drug_image/crop_images/ch4_crop/")

fns1.sort()
# fns2.sort()
fns3.sort()
fns4.sort()

for i in range(len(fns1)):
    ch1 = cv2.imread(f'./iso_drug_image/crop_images/ch1_crop/{fns1[i]}', cv2.IMREAD_UNCHANGED)
    # ch2 = cv2.imread(f'./angii_drug_image/crop_images/ch2_crop/{fns2[i]}', cv2.IMREAD_UNCHANGED)
    ch3 = cv2.imread(f'./iso_drug_image/crop_images/ch3_crop/{fns3[i]}', cv2.IMREAD_UNCHANGED)
    ch4 = cv2.imread(f'./iso_drug_image/crop_images/ch4_crop/{fns4[i]}', cv2.IMREAD_UNCHANGED)

    ch_merge = cv2.merge([ch1, ch3, ch4])
    cv2.imwrite(f'./iso_drug_image/crop_images/crop_merge_ch1ch3ch4/{fns1[i][:20]}{fns1[i][-11:]}', ch_merge)
